# %%
import pandas as pd
from sys import argv
import os
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
with open("task_4_data\data_dr3_75") as f:
    text = f.read()

data = pd.read_csv("task_4_data\data_dr3_75", sep=' ')
data.head()
# Out:
#    random_index  phot_g_mean_mag  phot_rp_mean_mag  phot_bp_mean_mag
# 0    1374168018        13.716302         12.788161         14.611763
# 1    1359579267        15.339891         14.632503         15.879703
# 2    1374362876        14.316683         13.340400         15.302835
# 3    1363439848        14.637045         13.615073         15.704117
# 4    1366836544        16.633352         15.743692         17.184544

# %%
plt.hist(data["phot_g_mean_mag"], bins = 100)
plt.xlabel("Apparent G magnitude")
plt.ylabel("Count")
plt.yscale('log')
plt.title("Distribution of the apparanet visual magnitude")
# Out:
# Text(0.5, 1.0, 'Distribution of the apparanet visual magnitude')

# %%
plt.hist(data["phot_bp_mean_mag"], bins = 100)
plt.xlabel("Apparent BP magnitude")
plt.ylabel("Count")
plt.yscale('log')
plt.title("Distribution of the apparanet BP magnitude")
# Out:
# Text(0.5, 1.0, 'Distribution of the apparanet BP magnitude')

# %%
plt.hist(data["phot_rp_mean_mag"], bins = 100)
plt.xlabel("Apparent RP magnitude")
plt.ylabel("Count")
plt.yscale('log')
plt.title("Distribution of the apparanet RP magnitude")
# Out:
# Text(0.5, 1.0, 'Distribution of the apparanet RP magnitude')

# %%
plt.hist(data["phot_g_mean_mag"], bins = 100, cumulative = True)
plt.xlabel("Apparent G magnitude")
plt.ylabel("Count")
plt.yscale('log')
plt.title("Distribution of the apparanet visual magnitude (Cumulative)")
# Out:
# Text(0.5, 1.0, 'Distribution of the apparanet visual magnitude (Cumulative)')
