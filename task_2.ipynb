# %%
import pandas as pd
from sys import argv
import os
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
with open("task_2_data\data_dr3_75") as f:
    text = f.read()

# %%
data = pd.read_csv("task_2_data\data_dr3_75", sep=' ')
data.head()
# Out:
#    random_index       pmra      pmdec
# 0    1374168018  -5.350211  -3.276386
# 1    1359579267  -1.258499  -3.901843
# 2    1374362876  -3.394367  -4.284133
# 3    1363439848  -0.525661  -3.745906
# 4    1366836544 -13.325053 -15.288217

# %%
plt.plot(data["pmra"], data["pmdec"], 'o', markersize = 0.3)
plt.xlabel("Proper motion in Right Ascension")
plt.ylabel("Proper motion in Declination")
plt.title ("Variation of proper motion")
plt.xlim(-50, 50)
plt.ylim(-50, 50)
plt.show()
